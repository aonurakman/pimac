# %%
import json
import os
import sys
from prettytable import PrettyTable

# %%
ALGORITHMS = [
    "ippo",
    "mappo",
    "pimac_v0",
    "pimac_v6"
]

NAME_MAP = {
    "ippo": "IPPO",
    "mappo": "MAPPO",
    "pimac_v0": "PIC-MAPPO",
    "pimac_v6": "TC3D"
}

TASKS = [
    "spread",
    "rware",
    "lbf_hard"
]

SEEDS = [42, 43, 44, 45, 46]

tc3d_selections = {
    "rware" : "active_01",
    "spread" : "active_03",
    "lbf_hard" : "active_01"
}
